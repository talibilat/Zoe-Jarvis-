# %%
import pyttsx3
engine = pyttsx3.init()
engine.say('Sally sells seashells by the seashore.')
engine.say('The quick brown fox jumped over the lazy dog.')
engine.runAndWait()

# %%
import pyttsx3
import pandas as pd

engine = pyttsx3.init()
voices = engine.getProperty("voices")

voice_data = []
for idx, v in enumerate(voices):
    voice_data.append({
        "Index": idx,
        "ID": v.id,
        "Name": v.name,
        "Languages": v.languages,
        "Gender": getattr(v, "gender", "Unknown"),
        "Age": getattr(v, "age", "Unknown")
    })

df = pd.DataFrame(voice_data)

# Ensure pandas prints all rows and columns
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# Print the full DataFrame
df
# Out:
#      Index                                           ID  \
# 0        0      com.apple.speech.synthesis.voice.Albert
# 1        1          com.apple.voice.compact.it-IT.Alice
# 2        2         com.apple.voice.compact.kn-IN.Alpana
# 3        3           com.apple.voice.compact.sv-SE.Alva
# 4        4                         com.apple.voice.Aman
# 5        5         com.apple.voice.compact.fr-CA.Amelie
# 6        6          com.apple.voice.compact.ms-MY.Amira
# 7        7           com.apple.voice.compact.de-DE.Anna
# 8        8                          com.apple.voice.Aru
# 9        9                  com.apple.voice.Aru.premium
# 10      10     com.apple.speech.synthesis.voice.BadNews
# 11      11        com.apple.speech.synthesis.voice.Bahh
# 12      12       com.apple.speech.synthesis.voice.Bells
# 13      13       com.apple.speech.synthesis.voice.Boing
# 14      14     com.apple.speech.synthesis.voice.Bubbles
# 15      15         com.apple.voice.compact.he-IL.Carmit
# 16      16      com.apple.speech.synthesis.voice.Cellos
# 17      17      com.apple.voice.compact.id-ID.Damayanti
# 18      18         com.apple.voice.compact.en-GB.Daniel
# 19      19          com.apple.voice.compact.bg-BG.Daria
# 20      20    com.apple.speech.synthesis.voice.Deranged
# 21      21               com.apple.eloquence.de-DE.Eddy
# 22      22               com.apple.eloquence.en-GB.Eddy
# 23      23               com.apple.eloquence.en-US.Eddy
# 24      24               com.apple.eloquence.es-ES.Eddy
# 25      25               com.apple.eloquence.es-MX.Eddy
# 26      26               com.apple.eloquence.fi-FI.Eddy
# 27      27               com.apple.eloquence.fr-CA.Eddy
# 28      28               com.apple.eloquence.fr-FR.Eddy
# 29      29               com.apple.eloquence.it-IT.Eddy
# 30      30               com.apple.eloquence.ja-JP.Eddy
# 31      31               com.apple.eloquence.ko-KR.Eddy
# 32      32               com.apple.eloquence.pt-BR.Eddy
# 33      33               com.apple.eloquence.zh-CN.Eddy
# 34      34               com.apple.eloquence.zh-TW.Eddy
# 35      35          com.apple.voice.compact.nl-BE.Ellen
# 36      36                com.apple.eloquence.de-DE.Flo
# 37      37                com.apple.eloquence.en-GB.Flo
# 38      38                com.apple.eloquence.en-US.Flo
# 39      39                com.apple.eloquence.es-ES.Flo
# 40      40                com.apple.eloquence.es-MX.Flo
# 41      41                com.apple.eloquence.fi-FI.Flo
# 42      42                com.apple.eloquence.fr-CA.Flo
# 43      43                com.apple.eloquence.fr-FR.Flo
# 44      44                com.apple.eloquence.it-IT.Flo
# 45      45                com.apple.eloquence.ja-JP.Flo
# 46      46                com.apple.eloquence.ko-KR.Flo
# 47      47                com.apple.eloquence.pt-BR.Flo
# 48      48                com.apple.eloquence.zh-CN.Flo
# 49      49                com.apple.eloquence.zh-TW.Flo
# 50      50        com.apple.speech.synthesis.voice.Fred
# 51      51          com.apple.voice.compact.te-IN.Geeta
# 52      52    com.apple.speech.synthesis.voice.GoodNews
# 53      53            com.apple.eloquence.de-DE.Grandma
# 54      54            com.apple.eloquence.en-GB.Grandma
# 55      55            com.apple.eloquence.en-US.Grandma
# 56      56            com.apple.eloquence.es-ES.Grandma
# 57      57            com.apple.eloquence.es-MX.Grandma
# 58      58            com.apple.eloquence.fi-FI.Grandma
# 59      59            com.apple.eloquence.fr-CA.Grandma
# 60      60            com.apple.eloquence.fr-FR.Grandma
# 61      61            com.apple.eloquence.it-IT.Grandma
# 62      62            com.apple.eloquence.ja-JP.Grandma
# 63      63            com.apple.eloquence.ko-KR.Grandma
# 64      64            com.apple.eloquence.pt-BR.Grandma
# 65      65            com.apple.eloquence.zh-CN.Grandma
# 66      66            com.apple.eloquence.zh-TW.Grandma
# 67      67            com.apple.eloquence.de-DE.Grandpa
# 68      68            com.apple.eloquence.en-GB.Grandpa
# 69      69            com.apple.eloquence.en-US.Grandpa
# 70      70            com.apple.eloquence.es-ES.Grandpa
# 71      71            com.apple.eloquence.es-MX.Grandpa
# 72      72            com.apple.eloquence.fi-FI.Grandpa
# 73      73            com.apple.eloquence.fr-CA.Grandpa
# 74      74            com.apple.eloquence.fr-FR.Grandpa
# 75      75            com.apple.eloquence.it-IT.Grandpa
# 76      76            com.apple.eloquence.ja-JP.Grandpa
# 77      77            com.apple.eloquence.ko-KR.Grandpa
# 78      78            com.apple.eloquence.pt-BR.Grandpa
# 79      79            com.apple.eloquence.zh-CN.Grandpa
# 80      80            com.apple.eloquence.zh-TW.Grandpa
# 81      81  com.apple.speech.synthesis.voice.Hysterical
# 82      82          com.apple.voice.compact.ro-RO.Ioana
# 83      83            com.apple.eloquence.fr-FR.Jacques
# 84      84          com.apple.voice.compact.pt-PT.Joana
# 85      85      com.apple.speech.synthesis.voice.Junior
# 86      86          com.apple.voice.compact.th-TH.Kanya
# 87      87          com.apple.voice.compact.en-AU.Karen
# 88      88       com.apple.speech.synthesis.voice.Kathy
# 89      89          com.apple.voice.compact.ja-JP.Kyoko
# 90      90           com.apple.voice.compact.hr-HR.Lana
# 91      91          com.apple.voice.compact.sk-SK.Laura
# 92      92          com.apple.voice.compact.hi-IN.Lekha
# 93      93          com.apple.voice.compact.uk-UA.Lesya
# 94      94           com.apple.voice.compact.vi-VN.Linh
# 95      95        com.apple.voice.compact.pt-BR.Luciana
# 96      96         com.apple.voice.compact.ar-001.Maged
# 97      97        com.apple.voice.compact.hu-HU.Mariska
# 98      98         com.apple.voice.compact.zh-TW.Meijia
# 99      99         com.apple.voice.compact.el-GR.Melina
# 100    100         com.apple.voice.compact.ru-RU.Milena
# 101    101          com.apple.voice.compact.en-IE.Moira
# 102    102         com.apple.voice.compact.es-ES.Monica
# 103    103     com.apple.voice.compact.ca-ES.Montserrat
# 104    104           com.apple.voice.compact.nb-NO.Nora
# 105    105                          com.apple.voice.Ona
# 106    106       com.apple.speech.synthesis.voice.Organ
# 107    107        com.apple.voice.compact.es-MX.Paulina
# 108    108           com.apple.voice.compact.bn-IN.Paya
# 109    109    com.apple.speech.synthesis.voice.Princess
# 110    110       com.apple.speech.synthesis.voice.Ralph
# 111    111               com.apple.eloquence.de-DE.Reed
# 112    112               com.apple.eloquence.en-GB.Reed
# 113    113               com.apple.eloquence.en-US.Reed
# 114    114               com.apple.eloquence.es-ES.Reed
# 115    115               com.apple.eloquence.es-MX.Reed
# 116    116               com.apple.eloquence.fi-FI.Reed
# 117    117               com.apple.eloquence.fr-CA.Reed
# 118    118               com.apple.eloquence.it-IT.Reed
# 119    119               com.apple.eloquence.ja-JP.Reed
# 120    120               com.apple.eloquence.ko-KR.Reed
# 121    121               com.apple.eloquence.pt-BR.Reed
# 122    122               com.apple.eloquence.zh-CN.Reed
# 123    123               com.apple.eloquence.zh-TW.Reed
# 124    124          com.apple.voice.compact.en-IN.Rishi
# 125    125              com.apple.eloquence.de-DE.Rocko
# 126    126              com.apple.eloquence.en-GB.Rocko
# 127    127              com.apple.eloquence.en-US.Rocko
# 128    128              com.apple.eloquence.es-ES.Rocko
# 129    129              com.apple.eloquence.es-MX.Rocko
# 130    130              com.apple.eloquence.fi-FI.Rocko
# 131    131              com.apple.eloquence.fr-CA.Rocko
# 132    132              com.apple.eloquence.fr-FR.Rocko
# 133    133              com.apple.eloquence.it-IT.Rocko
# 134    134              com.apple.eloquence.ja-JP.Rocko
# 135    135              com.apple.eloquence.ko-KR.Rocko
# 136    136              com.apple.eloquence.pt-BR.Rocko
# 137    137              com.apple.eloquence.zh-CN.Rocko
# 138    138              com.apple.eloquence.zh-TW.Rocko
# 139    139       com.apple.voice.compact.en-US.Samantha
# 140    140       com.apple.voice.compact.en-US.Samantha
# 141    141              com.apple.eloquence.de-DE.Sandy
# 142    142              com.apple.eloquence.en-GB.Sandy
# 143    143              com.apple.eloquence.en-US.Sandy
# 144    144              com.apple.eloquence.es-ES.Sandy
# 145    145              com.apple.eloquence.es-MX.Sandy
# 146    146              com.apple.eloquence.fi-FI.Sandy
# 147    147              com.apple.eloquence.fr-CA.Sandy
# 148    148              com.apple.eloquence.fr-FR.Sandy
# 149    149              com.apple.eloquence.it-IT.Sandy
# 150    150              com.apple.eloquence.ja-JP.Sandy
# 151    151              com.apple.eloquence.ko-KR.Sandy
# 152    152              com.apple.eloquence.pt-BR.Sandy
# 153    153              com.apple.eloquence.zh-CN.Sandy
# 154    154              com.apple.eloquence.zh-TW.Sandy
# 155    155           com.apple.voice.compact.da-DK.Sara
# 156    156           com.apple.voice.compact.fi-FI.Satu
# 157    157            com.apple.eloquence.de-DE.Shelley
# 158    158            com.apple.eloquence.en-GB.Shelley
# 159    159            com.apple.eloquence.en-US.Shelley
# 160    160            com.apple.eloquence.es-ES.Shelley
# 161    161            com.apple.eloquence.es-MX.Shelley
# 162    162            com.apple.eloquence.fi-FI.Shelley
# 163    163            com.apple.eloquence.fr-CA.Shelley
# 164    164            com.apple.eloquence.fr-FR.Shelley
# 165    165            com.apple.eloquence.it-IT.Shelley
# 166    166            com.apple.eloquence.ja-JP.Shelley
# 167    167            com.apple.eloquence.ko-KR.Shelley
# 168    168            com.apple.eloquence.pt-BR.Shelley
# 169    169            com.apple.eloquence.zh-CN.Shelley
# 170    170            com.apple.eloquence.zh-TW.Shelley
# 171    171          com.apple.voice.compact.zh-HK.Sinji
# 172    172                         com.apple.voice.Tara
# 173    173          com.apple.voice.compact.en-ZA.Tessa
# 174    174         com.apple.voice.compact.fr-FR.Thomas
# 175    175           com.apple.voice.compact.sl-SI.Tina
# 176    176       com.apple.voice.compact.zh-CN.Tingting
# 177    177    com.apple.speech.synthesis.voice.Trinoids
# 178    178           com.apple.voice.compact.ta-IN.Vani
# 179    179     com.apple.speech.synthesis.voice.Whisper
# 180    180         com.apple.voice.compact.nl-NL.Xander
# 181    181          com.apple.voice.compact.tr-TR.Yelda
# 182    182           com.apple.voice.compact.ko-KR.Yuna
# 183    183      com.apple.speech.synthesis.voice.Zarvox
# 184    184          com.apple.voice.compact.pl-PL.Zosia
# 185    185         com.apple.voice.compact.cs-CZ.Zuzana
#
#                                    Name Languages             Gender   Age
# 0                                Albert   [en_US]  VoiceGenderNeuter  None
# 1                                 Alice   [it_IT]  VoiceGenderFemale  None
# 2                                Soumya   [kn_IN]  VoiceGenderFemale  None
# 3                                  Alva   [sv_SE]  VoiceGenderFemale  None
# 4                                  Aman   [en_IN]    VoiceGenderMale  None
# 5                                Amélie   [fr_CA]  VoiceGenderFemale  None
# 6                                 Amira   [ms_MY]  VoiceGenderFemale  None
# 7                                  Anna   [de_DE]  VoiceGenderFemale  None
# 8                          Aru ((null))   [kk_KZ]  VoiceGenderFemale  None
# 9                          Aru ((null))   [kk_KZ]  VoiceGenderFemale  None
# 10                             Bad News   [en_US]  VoiceGenderNeuter  None
# 11                                 Bahh   [en_US]  VoiceGenderNeuter  None
# 12                                Bells   [en_US]  VoiceGenderNeuter  None
# 13                                Boing   [en_US]  VoiceGenderNeuter  None
# 14                              Bubbles   [en_US]  VoiceGenderNeuter  None
# 15                               Carmit   [he_IL]  VoiceGenderFemale  None
# 16                               Cellos   [en_US]  VoiceGenderNeuter  None
# 17                            Damayanti   [id_ID]  VoiceGenderFemale  None
# 18                               Daniel   [en_GB]    VoiceGenderMale  None
# 19                                Daria   [bg_BG]  VoiceGenderFemale  None
# 20                               Wobble   [en_US]  VoiceGenderNeuter  None
# 21              Eddy (German (Germany))   [de_DE]  VoiceGenderNeuter  None
# 22                  Eddy (English (UK))   [en_GB]  VoiceGenderNeuter  None
# 23                  Eddy (English (US))   [en_US]  VoiceGenderNeuter  None
# 24               Eddy (Spanish (Spain))   [es_ES]  VoiceGenderNeuter  None
# 25              Eddy (Spanish (Mexico))   [es_MX]  VoiceGenderNeuter  None
# 26             Eddy (Finnish (Finland))   [fi_FI]  VoiceGenderNeuter  None
# 27               Eddy (French (Canada))   [fr_CA]  VoiceGenderNeuter  None
# 28               Eddy (French (France))   [fr_FR]  VoiceGenderNeuter  None
# 29               Eddy (Italian (Italy))   [it_IT]  VoiceGenderNeuter  None
# 30              Eddy (Japanese (Japan))   [ja_JP]  VoiceGenderNeuter  None
# 31          Eddy (Korean (South Korea))   [ko_KR]  VoiceGenderNeuter  None
# 32           Eddy (Portuguese (Brazil))   [pt_BR]  VoiceGenderNeuter  None
# 33      Eddy (Chinese (China mainland))   [zh_CN]  VoiceGenderNeuter  None
# 34              Eddy (Chinese (Taiwan))   [zh_TW]  VoiceGenderNeuter  None
# 35                                Ellen   [nl_BE]  VoiceGenderFemale  None
# 36               Flo (German (Germany))   [de_DE]  VoiceGenderNeuter  None
# 37                   Flo (English (UK))   [en_GB]  VoiceGenderNeuter  None
# 38                   Flo (English (US))   [en_US]  VoiceGenderNeuter  None
# 39                Flo (Spanish (Spain))   [es_ES]  VoiceGenderNeuter  None
# 40               Flo (Spanish (Mexico))   [es_MX]  VoiceGenderNeuter  None
# 41              Flo (Finnish (Finland))   [fi_FI]  VoiceGenderNeuter  None
# 42                Flo (French (Canada))   [fr_CA]  VoiceGenderNeuter  None
# 43                Flo (French (France))   [fr_FR]  VoiceGenderNeuter  None
# 44                Flo (Italian (Italy))   [it_IT]  VoiceGenderNeuter  None
# 45               Flo (Japanese (Japan))   [ja_JP]  VoiceGenderNeuter  None
# 46           Flo (Korean (South Korea))   [ko_KR]  VoiceGenderNeuter  None
# 47            Flo (Portuguese (Brazil))   [pt_BR]  VoiceGenderNeuter  None
# 48       Flo (Chinese (China mainland))   [zh_CN]  VoiceGenderNeuter  None
# 49               Flo (Chinese (Taiwan))   [zh_TW]  VoiceGenderNeuter  None
# 50                                 Fred   [en_US]    VoiceGenderMale  None
# 51                                Geeta   [te_IN]  VoiceGenderFemale  None
# 52                            Good News   [en_US]  VoiceGenderNeuter  None
# 53           Grandma (German (Germany))   [de_DE]  VoiceGenderNeuter  None
# 54               Grandma (English (UK))   [en_GB]  VoiceGenderNeuter  None
# 55               Grandma (English (US))   [en_US]  VoiceGenderNeuter  None
# 56            Grandma (Spanish (Spain))   [es_ES]  VoiceGenderNeuter  None
# 57           Grandma (Spanish (Mexico))   [es_MX]  VoiceGenderNeuter  None
# 58          Grandma (Finnish (Finland))   [fi_FI]  VoiceGenderNeuter  None
# 59            Grandma (French (Canada))   [fr_CA]  VoiceGenderNeuter  None
# 60            Grandma (French (France))   [fr_FR]  VoiceGenderNeuter  None
# 61            Grandma (Italian (Italy))   [it_IT]  VoiceGenderNeuter  None
# 62           Grandma (Japanese (Japan))   [ja_JP]  VoiceGenderNeuter  None
# 63       Grandma (Korean (South Korea))   [ko_KR]  VoiceGenderNeuter  None
# 64        Grandma (Portuguese (Brazil))   [pt_BR]  VoiceGenderNeuter  None
# 65   Grandma (Chinese (China mainland))   [zh_CN]  VoiceGenderNeuter  None
# 66           Grandma (Chinese (Taiwan))   [zh_TW]  VoiceGenderNeuter  None
# 67           Grandpa (German (Germany))   [de_DE]  VoiceGenderNeuter  None
# 68               Grandpa (English (UK))   [en_GB]  VoiceGenderNeuter  None
# 69               Grandpa (English (US))   [en_US]  VoiceGenderNeuter  None
# 70            Grandpa (Spanish (Spain))   [es_ES]  VoiceGenderNeuter  None
# 71           Grandpa (Spanish (Mexico))   [es_MX]  VoiceGenderNeuter  None
# 72          Grandpa (Finnish (Finland))   [fi_FI]  VoiceGenderNeuter  None
# 73            Grandpa (French (Canada))   [fr_CA]  VoiceGenderNeuter  None
# 74            Grandpa (French (France))   [fr_FR]  VoiceGenderNeuter  None
# 75            Grandpa (Italian (Italy))   [it_IT]  VoiceGenderNeuter  None
# 76           Grandpa (Japanese (Japan))   [ja_JP]  VoiceGenderNeuter  None
# 77       Grandpa (Korean (South Korea))   [ko_KR]  VoiceGenderNeuter  None
# 78        Grandpa (Portuguese (Brazil))   [pt_BR]  VoiceGenderNeuter  None
# 79   Grandpa (Chinese (China mainland))   [zh_CN]  VoiceGenderNeuter  None
# 80           Grandpa (Chinese (Taiwan))   [zh_TW]  VoiceGenderNeuter  None
# 81                               Jester   [en_US]  VoiceGenderNeuter  None
# 82                                Ioana   [ro_RO]  VoiceGenderFemale  None
# 83                              Jacques   [fr_FR]  VoiceGenderNeuter  None
# 84                                Joana   [pt_PT]  VoiceGenderFemale  None
# 85                               Junior   [en_US]  VoiceGenderNeuter  None
# 86                                Kanya   [th_TH]  VoiceGenderFemale  None
# 87                                Karen   [en_AU]  VoiceGenderFemale  None
# 88                                Kathy   [en_US]  VoiceGenderNeuter  None
# 89                                Kyoko   [ja_JP]  VoiceGenderFemale  None
# 90                                 Lana   [hr_HR]  VoiceGenderFemale  None
# 91                                Laura   [sk_SK]  VoiceGenderFemale  None
# 92                                Lekha   [hi_IN]  VoiceGenderFemale  None
# 93                                Lesya   [uk_UA]  VoiceGenderFemale  None
# 94                                 Linh   [vi_VN]  VoiceGenderFemale  None
# 95                              Luciana   [pt_BR]  VoiceGenderFemale  None
# 96                                Majed  [ar_001]    VoiceGenderMale  None
# 97                                Tünde   [hu_HU]  VoiceGenderFemale  None
# 98                               Meijia   [zh_TW]  VoiceGenderFemale  None
# 99                               Melina   [el_GR]  VoiceGenderFemale  None
# 100                              Milena   [ru_RU]  VoiceGenderFemale  None
# 101                               Moira   [en_IE]  VoiceGenderFemale  None
# 102                              Mónica   [es_ES]  VoiceGenderFemale  None
# 103                              Montse   [ca_ES]  VoiceGenderFemale  None
# 104                                Nora   [nb_NO]  VoiceGenderFemale  None
# 105                                 Ona   [lt_LT]  VoiceGenderFemale  None
# 106                               Organ   [en_US]  VoiceGenderNeuter  None
# 107                             Paulina   [es_MX]  VoiceGenderFemale  None
# 108                                Piya   [bn_IN]  VoiceGenderFemale  None
# 109                           Superstar   [en_US]  VoiceGenderNeuter  None
# 110                               Ralph   [en_US]  VoiceGenderNeuter  None
# 111             Reed (German (Germany))   [de_DE]  VoiceGenderNeuter  None
# 112                 Reed (English (UK))   [en_GB]  VoiceGenderNeuter  None
# 113                 Reed (English (US))   [en_US]  VoiceGenderNeuter  None
# 114              Reed (Spanish (Spain))   [es_ES]  VoiceGenderNeuter  None
# 115             Reed (Spanish (Mexico))   [es_MX]  VoiceGenderNeuter  None
# 116            Reed (Finnish (Finland))   [fi_FI]  VoiceGenderNeuter  None
# 117              Reed (French (Canada))   [fr_CA]  VoiceGenderNeuter  None
# 118              Reed (Italian (Italy))   [it_IT]  VoiceGenderNeuter  None
# 119             Reed (Japanese (Japan))   [ja_JP]  VoiceGenderNeuter  None
# 120         Reed (Korean (South Korea))   [ko_KR]  VoiceGenderNeuter  None
# 121          Reed (Portuguese (Brazil))   [pt_BR]  VoiceGenderNeuter  None
# 122     Reed (Chinese (China mainland))   [zh_CN]  VoiceGenderNeuter  None
# 123             Reed (Chinese (Taiwan))   [zh_TW]  VoiceGenderNeuter  None
# 124                               Rishi   [en_IN]    VoiceGenderMale  None
# 125            Rocko (German (Germany))   [de_DE]  VoiceGenderNeuter  None
# 126                Rocko (English (UK))   [en_GB]  VoiceGenderNeuter  None
# 127                Rocko (English (US))   [en_US]  VoiceGenderNeuter  None
# 128             Rocko (Spanish (Spain))   [es_ES]  VoiceGenderNeuter  None
# 129            Rocko (Spanish (Mexico))   [es_MX]  VoiceGenderNeuter  None
# 130           Rocko (Finnish (Finland))   [fi_FI]  VoiceGenderNeuter  None
# 131             Rocko (French (Canada))   [fr_CA]  VoiceGenderNeuter  None
# 132             Rocko (French (France))   [fr_FR]  VoiceGenderNeuter  None
# 133             Rocko (Italian (Italy))   [it_IT]  VoiceGenderNeuter  None
# 134            Rocko (Japanese (Japan))   [ja_JP]  VoiceGenderNeuter  None
# 135        Rocko (Korean (South Korea))   [ko_KR]  VoiceGenderNeuter  None
# 136         Rocko (Portuguese (Brazil))   [pt_BR]  VoiceGenderNeuter  None
# 137    Rocko (Chinese (China mainland))   [zh_CN]  VoiceGenderNeuter  None
# 138            Rocko (Chinese (Taiwan))   [zh_TW]  VoiceGenderNeuter  None
# 139             Samantha (English (US))   [en_US]  VoiceGenderFemale  None
# 140             Samantha (English (US))   [en_US]  VoiceGenderFemale  None
# 141            Sandy (German (Germany))   [de_DE]  VoiceGenderNeuter  None
# 142                Sandy (English (UK))   [en_GB]  VoiceGenderNeuter  None
# 143                Sandy (English (US))   [en_US]  VoiceGenderNeuter  None
# 144             Sandy (Spanish (Spain))   [es_ES]  VoiceGenderNeuter  None
# 145            Sandy (Spanish (Mexico))   [es_MX]  VoiceGenderNeuter  None
# 146           Sandy (Finnish (Finland))   [fi_FI]  VoiceGenderNeuter  None
# 147             Sandy (French (Canada))   [fr_CA]  VoiceGenderNeuter  None
# 148             Sandy (French (France))   [fr_FR]  VoiceGenderNeuter  None
# 149             Sandy (Italian (Italy))   [it_IT]  VoiceGenderNeuter  None
# 150            Sandy (Japanese (Japan))   [ja_JP]  VoiceGenderNeuter  None
# 151        Sandy (Korean (South Korea))   [ko_KR]  VoiceGenderNeuter  None
# 152         Sandy (Portuguese (Brazil))   [pt_BR]  VoiceGenderNeuter  None
# 153    Sandy (Chinese (China mainland))   [zh_CN]  VoiceGenderNeuter  None
# 154            Sandy (Chinese (Taiwan))   [zh_TW]  VoiceGenderNeuter  None
# 155                                Sara   [da_DK]  VoiceGenderFemale  None
# 156                                Satu   [fi_FI]  VoiceGenderFemale  None
# 157          Shelley (German (Germany))   [de_DE]  VoiceGenderNeuter  None
# 158              Shelley (English (UK))   [en_GB]  VoiceGenderNeuter  None
# 159              Shelley (English (US))   [en_US]  VoiceGenderNeuter  None
# 160           Shelley (Spanish (Spain))   [es_ES]  VoiceGenderNeuter  None
# 161          Shelley (Spanish (Mexico))   [es_MX]  VoiceGenderNeuter  None
# 162         Shelley (Finnish (Finland))   [fi_FI]  VoiceGenderNeuter  None
# 163           Shelley (French (Canada))   [fr_CA]  VoiceGenderNeuter  None
# 164           Shelley (French (France))   [fr_FR]  VoiceGenderNeuter  None
# 165           Shelley (Italian (Italy))   [it_IT]  VoiceGenderNeuter  None
# 166          Shelley (Japanese (Japan))   [ja_JP]  VoiceGenderNeuter  None
# 167      Shelley (Korean (South Korea))   [ko_KR]  VoiceGenderNeuter  None
# 168       Shelley (Portuguese (Brazil))   [pt_BR]  VoiceGenderNeuter  None
# 169  Shelley (Chinese (China mainland))   [zh_CN]  VoiceGenderNeuter  None
# 170          Shelley (Chinese (Taiwan))   [zh_TW]  VoiceGenderNeuter  None
# 171                               Sinji   [zh_HK]  VoiceGenderFemale  None
# 172                                Tara   [en_IN]  VoiceGenderFemale  None
# 173                               Tessa   [en_ZA]  VoiceGenderFemale  None
# 174                              Thomas   [fr_FR]    VoiceGenderMale  None
# 175                                Tina   [sl_SI]  VoiceGenderFemale  None
# 176                            Tingting   [zh_CN]  VoiceGenderFemale  None
# 177                            Trinoids   [en_US]  VoiceGenderNeuter  None
# 178                                Vani   [ta_IN]  VoiceGenderFemale  None
# 179                             Whisper   [en_US]  VoiceGenderNeuter  None
# 180                              Xander   [nl_NL]    VoiceGenderMale  None
# 181                               Yelda   [tr_TR]  VoiceGenderFemale  None
# 182                                Yuna   [ko_KR]  VoiceGenderFemale  None
# 183                              Zarvox   [en_US]  VoiceGenderNeuter  None
# 184                               Zosia   [pl_PL]  VoiceGenderFemale  None
# 185                              Zuzana   [cs_CZ]  VoiceGenderFemale  None
